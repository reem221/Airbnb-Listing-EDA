# %%
#import library
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
df=pd.read_csv('listings.csv')
df.head()
# Out:
#         id                           listing_url       scrape_id last_scraped  \
# 0  1489424  https://www.airbnb.com/rooms/1489424  20240408160234   2024-04-08
# 1  2992450  https://www.airbnb.com/rooms/2992450  20240408160234   2024-04-08
# 2  3820211  https://www.airbnb.com/rooms/3820211  20240408160234   2024-04-08
# 3  5651579  https://www.airbnb.com/rooms/5651579  20240408160234   2024-04-08
# 4  6623339  https://www.airbnb.com/rooms/6623339  20240408160234   2024-04-08
#
#         source                                              name  \
# 0  city scrape     Welcoming, easygoing, comfy bed, entire level
# 1  city scrape                        Luxury 2 bedroom apartment
# 2  city scrape         Restored Precinct in Center Sq. w/Parking
# 3  city scrape        Large studio apt  by Capital Center & ESP@
# 4  city scrape  Center Sq. Loft in Converted Precinct w/ Parking
#
#                                          description  \
# ...

# %%
# Display summary information
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 75 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            395 non-null    int64
#  1   listing_url                                   395 non-null    object
#  2   scrape_id                                     395 non-null    int64
#  3   last_scraped                                  395 non-null    object
#  4   source                                        395 non-null    object
#  5   name                                          395 non-null    object
#  6   description                                   385 non-null    object
#  7   neighborhood_overview                         235 non-null    object
#  8   picture_url                                   395 non-null    object
# ...

# %%
# Handling missing values
missing_values = df.isnull().sum()
missing_values = missing_values[missing_values > 0]
print("Columns with missing values:\n", missing_values)
df.drop(['neighbourhood_group_cleansed','calendar_updated','license'], axis=1, inplace=True)
# Out:
# Columns with missing values:
#  description                      10
# neighborhood_overview           160
# host_location                    94
# host_about                      189
# host_response_time               25
# host_response_rate               25
# host_acceptance_rate             14
# host_is_superhost                 5
# host_neighbourhood               72
# neighbourhood                   160
# neighbourhood_group_cleansed    395
# bathrooms                        17
# bedrooms                          2
# beds                             18
# price                            17
# calendar_updated                395
# has_availability                  2
# first_review                     43
# last_review                      43
# review_scores_rating             43
# review_scores_accuracy           43
# review_scores_cleanliness        43
# review_scores_checkin            43
# review_scores_communication      43
# review_scores_location           43
# ...

# %%
# Import necessary libraries for data visualization
import matplotlib.pyplot as plt
import seaborn as sns
# Price Analysis
# Set up the figure for plotting with a specified size
plt.figure(figsize=(10, 6))
# Create a distribution plot of the 'price' column from the DataFrame 'df'
# with a Kernel Density Estimate (KDE) to show the distribution shape
sns.displot(df['price'], kde=True)
# Add a title and labels to the plot
plt.title('Distribution of Prices')
plt.xlabel('Price')
plt.ylabel('Frequency')
# Save the plot as an image file in the specified directory
plt.savefig('E:\\reem\\electro pi\\Exploratory data\\Distribution of Prices.png')
# Display the plot on the screen
plt.show()

# %%
# availability Analysis
# Set up the figure for plotting with a specified size
plt.figure(figsize=(10, 6))
# Create a distribution plot of the 'availability_365' column from the DataFrame 'df'
# with a Kernel Density Estimate (KDE) to show the distribution shape
sns.displot(df['availability_365'], kde=True)
# Add a title and labels to the plot
plt.title('Availability Distribution')
plt.xlabel('Days Available')
plt.ylabel('Frequency')
# Save the plot as an image file in the specified directory
plt.savefig('E:\\reem\\electro pi\\Exploratory data\\availability_distribution.png')
# Display the plot on the screen
plt.show()

# %%
# Location Analysis (using latitude and longitude)
# Set up the figure for plotting with a specified size
plt.figure(figsize=(10, 6))
# Create a scatter plot showing the relationship between 'longitude' and 'latitude'
# The color of the points is determined by the 'price' column, using the 'viridis' color palette
sns.scatterplot(x='longitude', y='latitude', hue='price', data=df, palette='viridis')
# Add a title and labels to the plot
plt.title('Price Distribution by Location')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
# Save the plot as an image file in the specified directory
plt.savefig('E:\\reem\\electro pi\\Exploratory data\\Price Distribution by Location.png')
# Display the plot on the screen
plt.show()

# %%
# Property Type Analysis
# Set up the figure for plotting with a specified size
plt.figure(figsize=(10, 6))
# Create a count plot for the 'property_type' column from the DataFrame 'df'
# The order of the bars is determined by the frequency of each property type
sns.countplot(y='property_type', data=df, order=df['property_type'].value_counts().index)
# Add a title and labels to the plot
plt.title('Property Type Distribution')
plt.xlabel('Count')
plt.ylabel('Property Type')
# Save the plot as an image file in the specified directory
plt.savefig('E:\\reem\\electro pi\\Exploratory data\\property_type_distribution.png')
# Display the plot on the screen
plt.show()

# %%
# Select all columns from the DataFrame 'df' that have numeric data types
# and store them in a new DataFrame 'data'
data = df.select_dtypes(include='number')

# Correlation Analysis
# Set up the figure for plotting with a large size
plt.figure(figsize=(30, 30))
# Create a heatmap of the correlation matrix for the numeric columns in 'data'
# The 'annot=True' parameter adds numerical annotations to each cell in the heatmap
sns.heatmap(data.corr(),annot=True)
# Add a title to the plot
plt.title('Correlation Matrix')
# Save the plot as an image file in the specified directory
plt.savefig('E:\\reem\\electro pi\\Exploratory data\\correlation_matrix.png')
# Display the plot on the screen
plt.show()

# %%
# Example Insight
print("Insight: The majority of listings are apartments, and they tend to have higher prices compared to other property types.")

# Recommendations
print("Recommendation: To attract more budget-conscious travelers, consider increasing the number of listings with lower prices and promoting them effectively.")
# Out:
# Insight: The majority of listings are apartments, and they tend to have higher prices compared to other property types.
# Recommendation: To attract more budget-conscious travelers, consider increasing the number of listings with lower prices and promoting them effectively.
